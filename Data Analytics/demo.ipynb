# %%
a=10

# %%
b=20

# %%
c=a+b

# %%
c
# Out:
# 30

# %%
a=20
b=40
c=a-b
c
# Out:
# -20

# %%
a=10

# %%
b=3

# %%
c=a^b

# %%
c
# Out:
# 9

# %%
c=a*a*a

# %%
c
# Out:
# 1000

# %%
a=3
b=4
c=1
for i in range(b):
    c = c*a
print(c)
# Out:
# 81

# %%
def addition(a,b):
    c= a+b

# %%
a=10
b=20
addition(a,b)

# %%
import numpy as np

# %% [markdown]
# we are learining numpy

# %% [markdown]
# addition of 2 list of index

# %%
li1 = [1,2,3,4]
li2=[5,6,7,8]
res =[]
for i in range(len(li1)):
    res.append(li1[i]+li2[i])
print (res)
# Out:
# [6, 8, 10, 12]

# %% [markdown]
# we use array
# array : is homogenous collection of data (similar type of data).
#         order collection (we do indexing)

# %%
li1 =[1,2,3]
li2 =[4,5,6]
res = list(map(lambda x,y : x+y ,li1,li2))
print(res)
# Out:
# [5, 7, 9]

# %%
li1 =[1,2,3]
li2 =[4,5,6]
#li3 = li1-li2 error
#li1 *5 repet the list

# %%
arr1 = np.array([1,2,4,5])
arr1
# Out:
# array([1, 2, 4, 5])

# %%
arr2 = np.array([5,6,7,8])
arr2
# Out:
# array([5, 6, 7, 8])

# %%
arr3 = arr1 + arr2
arr3
# Out:
# array([ 6,  8, 11, 13])

# %%
arr3 = arr1 - arr2
arr3
# Out:
# array([-4, -4, -3, -3])

# %%
arr3 = np.array([10,20,30,40])
arr3 *5
# Out:
# array([ 50, 100, 150, 200])

# %%
## vectorization 
1. when we
