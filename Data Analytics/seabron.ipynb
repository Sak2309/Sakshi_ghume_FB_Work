# %%
import seaborn as sns

# %%
import pandas as pd

# %%
data = pd.read_csv("dataset/Iris.csv")

# %%
data.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.histplot(data=data,x='Sepal_Length')
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Count'>

# %% [markdown]
# **kde = True is used to distribution of curved**

# %%
sns.histplot(data=data,x='Sepal_Length',kde = True)
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Count'>

# %% [markdown]
# # 11-2-2026

# %% [markdown]
# # 1.single column :
#         NUMARIC DATA :
#             1.histogram
#             2.boxplot
#         CATAGARICAL DATA :
#              1.barchart
#             2.pie chart
# # 2. 2 cloumns :
#         NUMARIC DATA :
#             1.line chart
#             2.scatterplot
# # 3. multiple cloumns :
#             NUMARIC DATA :
#                  1.heatmap

# %%
sns.scatterplot(data=data,x='Sepal_Length',y='Sepal_Width')
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Sepal_Width'>

# %% [markdown]
# **hue used to color**

# %%
sns.scatterplot(data =data,x='Sepal_Length',y='Sepal_Width',hue='Species')
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Sepal_Width'>

# %%
data['Species'].value_counts()
# Out:
# Species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# **countplot =which count the plots and given in graph format**

# %%
sns.countplot(data = data,x='Species')
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
data = pd.read_csv("dataset/cars93.csv")

# %%
data.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
sns.countplot(data =data,x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
data[['Type','AirBags']].value_counts()
# Out:
# Type     AirBags
# Small    Driver only           14
# Midsize  Driver only           13
# Compact  Driver only           10
# Sporty   Driver only            9
# Midsize  Driver & Passenger     8
# Large    Driver only            7
# Sporty   Driver & Passenger     4
# Van      Driver only            4
# Large    Driver & Passenger     4
# Compact  Driver & Passenger     3
# Van      Driver & Passenger     3
# Name: count, dtype: int64

# %%
sns.countplot(data= data,x='Type',hue ='AirBags')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %% [markdown]
# **find out avg mpg for each car**

# %%
data.groupby('Type')['MPG.city'].mean()
# Out:
# Type
# Compact    22.687500
# Large      18.363636
# Midsize    19.545455
# Small      29.857143
# Sporty     21.785714
# Van        17.000000
# Name: MPG.city, dtype: float64

# %%
sns.barplot(data = data,x='Type',y='MPG.city')
# Out:
# <Axes: xlabel='Type', ylabel='MPG.city'>

# %% [markdown]
# **seborn not used piechar**

# %%
sns.pairplot(data=data)

# %%
data =pd.read_csv("dataset/Iris.csv")

# %%
data.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.pairplot(data=data)

# %% [markdown]
# # 1.string (catagarial)column get ingnor
# # 2.numaric value scattedplot
# # 3.same column histogram

# %%
sns.pairplot(data =data, hue = 'Species')

# %% [markdown]
# # 1.cloumn same get distributed curved.
# # 2. scattelplot numaric data
